# %% [markdown]
# # UDEMY COURSE DATASET

# %%
# Import the required libraries:
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt # visualizing data
import seaborn as sns

# %%
df=pd.read_csv('7. Udemy Courses.csv') #Load the dataset into a pandas DataFrame:

# %% [markdown]
# # Some basic information of  Udemy dataset

# %% [markdown]
# ## Explore the dataset to understand its structure:

# %%
df.head() ## Display the first few rows to see the column names and sample data
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2    1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3    1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4    1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
#
#    price  num_subscribers  num_reviews  num_lectures               level  \
# 0   35.0             3137           18            68          All Levels
# 1   75.0             1593            1            41  Intermediate Level
# 2   75.0              482            1            47  Intermediate Level
# 3   75.0              850            3            43  Intermediate Level
# 4   75.0              940            3            32  Intermediate Level
#
#   content_duration       published_timestamp              subject
# ...

# %%
df.info()  # Get an overview of the dataset, including column types and missing values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3682 entries, 0 to 3681
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3682 non-null   int64
#  1   course_title         3682 non-null   object
#  2   is_paid              3682 non-null   bool
#  3   price                3372 non-null   float64
#  4   num_subscribers      3682 non-null   int64
#  5   num_reviews          3682 non-null   int64
#  6   num_lectures         3682 non-null   int64
#  7   level                3682 non-null   object
#  8   content_duration     3682 non-null   object
#  9   published_timestamp  3682 non-null   datetime64[ns, UTC]
#  10  subject              3682 non-null   object
# dtypes: bool(1), datetime64[ns, UTC](1), float64(1), int64(4), object(4)
# memory usage: 291.4+ KB

# %%
df.shape
# Out:
# (3682, 11)

# %%
df.head()
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2    1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3    1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4    1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
#
#    price  num_subscribers  num_reviews  num_lectures               level  \
# 0   35.0             3137           18            68          All Levels
# 1   75.0             1593            1            41  Intermediate Level
# 2   75.0              482            1            47  Intermediate Level
# 3   75.0              850            3            43  Intermediate Level
# 4   75.0              940            3            32  Intermediate Level
#
#   content_duration   published_timestamp              subject
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3682 entries, 0 to 3681
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3682 non-null   int64
#  1   course_title         3682 non-null   object
#  2   is_paid              3682 non-null   bool
#  3   price                3682 non-null   object
#  4   num_subscribers      3682 non-null   int64
#  5   num_reviews          3682 non-null   int64
#  6   num_lectures         3682 non-null   int64
#  7   level                3682 non-null   object
#  8   content_duration     3682 non-null   object
#  9   published_timestamp  3682 non-null   object
#  10  subject              3682 non-null   object
# dtypes: bool(1), int64(4), object(6)
# memory usage: 291.4+ KB

# %%
df.columns
# Out:
# Index(['course_id', 'course_title', 'is_paid', 'price', 'num_subscribers',
#        'num_reviews', 'num_lectures', 'level', 'content_duration',
#        'published_timestamp', 'subject'],
#       dtype='object')

# %%
df.count
# Out:
# <bound method DataFrame.count of       course_id                                       course_title  is_paid  \
# 0        288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1       1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2       1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3       1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4       1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
# ...         ...                                                ...      ...
# 3677     328960  Your Own Site in 45 Min: The Complete Wordpres...     True
# 3678     552700    Your Second Course on Piano: Two Handed Playing     True
# 3679     631754  Zend Framework 2: Learn the PHP framework ZF2 ...     True
# 3680    1225194  Zoho Books Gestion Financière d'Entreprise pas...    False
# 3681     964478                Zombie Apocalypse Photoshop Actions     True
#
# ...

# %%
df.isnull().sum()
# Out:
# course_id              0
# course_title           0
# is_paid                0
# price                  0
# num_subscribers        0
# num_reviews            0
# num_lectures           0
# level                  0
# content_duration       0
# published_timestamp    0
# subject                0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df.corr
# Out:
# <bound method DataFrame.corr of       course_id                                       course_title  is_paid  \
# 0        288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1       1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2       1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3       1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4       1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
# ...         ...                                                ...      ...
# 3677     328960  Your Own Site in 45 Min: The Complete Wordpres...     True
# 3678     552700    Your Second Course on Piano: Two Handed Playing     True
# 3679     631754  Zend Framework 2: Learn the PHP framework ZF2 ...     True
# 3680    1225194  Zoho Books Gestion Financière d'Entreprise pas...    False
# 3681     964478                Zombie Apocalypse Photoshop Actions     True
#
# ...

# %% [markdown]
# # Q. 1) What are all different subjects for which Udemy is offering courses ?

# %%
df.head(2)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
#
#   content_duration   published_timestamp              subject
# 0        1.5 hours  2014-09-18T05:07:05Z  Musical Instruments
# 1           1 hour  2017-04-12T19:06:34Z  Musical Instruments

# %%
df['subject'].unique()
# Out:
# array(['Musical Instruments', 'Business Finance', 'Graphic Design',
#        'Web Development'], dtype=object)

# %% [markdown]
# # Q. 2) Which subject has the maximum number of courses.

# %%
frequency = df['subject'].value_counts()
max_frequency_value = frequency.idxmax()
print("The subject has maximum numbers of courses =",max_frequency_value)
# Out:
# The subject has maximum numbers of courses = Web Development

# %% [markdown]
# # Q. 3) Show all the courses which are Free of Cost.

# %%
df.head()
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2    1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3    1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4    1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
# 2    75              482            1            47  Intermediate Level
# 3    75              850            3            43  Intermediate Level
# 4    75              940            3            32  Intermediate Level
#
#   content_duration   published_timestamp              subject
# ...

# %%
df[df['is_paid'] == False].head()
# Out:
#     course_id                                       course_title  is_paid  \
# 41     286070        5 lecciones que todo guitarrista debe tomar    False
# 49     696630  7 Ways A Beginner Guitarist Can Sound Better, ...    False
# 57     955914  A beginner`s guide to fingerpicking and strumm...    False
# 67     270976                             A how to guide in HTML    False
# 74    1214144  ¡Triunfar en La Bolsa de Valores No Requiere d...    False
#
#     price  num_subscribers  num_reviews  num_lectures           level  \
# 41    NaN             4452          263            14  Beginner Level
# 49    NaN             4529          193             7  Beginner Level
# 57    NaN             3481           29            20  Beginner Level
# 67    NaN             7318          205             8  Beginner Level
# 74    NaN              338            7             6  Beginner Level
#
#    content_duration       published_timestamp              subject
# ...

# %% [markdown]
# # Q. 4) Show all the courses which are Paid.

# %%
df[df['is_paid'] == True].head()
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2    1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3    1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4    1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
#
#    price  num_subscribers  num_reviews  num_lectures               level  \
# 0   35.0             3137           18            68          All Levels
# 1   75.0             1593            1            41  Intermediate Level
# 2   75.0              482            1            47  Intermediate Level
# 3   75.0              850            3            43  Intermediate Level
# 4   75.0              940            3            32  Intermediate Level
#
#   content_duration       published_timestamp              subject
# ...

# %% [markdown]
# # Q. 5) Which are Top Selling Courses ?

# %%
df.sort_values('num_subscribers', ascending=False).head()
# Out:
#       course_id                                       course_title  is_paid  \
# 2230      41295               Learn HTML5 Programming From Scratch    False
# 776       59014                     Coding for Entrepreneurs Basic    False
# 3385     625204                         The Web Developer Bootcamp     True
# 640      173548  Build Your First Website in 1 Week with HTML5 ...    False
# 3316     764164              The Complete Web Developer Course 2.0     True
#
#      price  num_subscribers  num_reviews  num_lectures           level  \
# 2230  Free           268923         8629            45      All Levels
# 776   Free           161029          279            27  Beginner Level
# 3385   200           121584        27445           342      All Levels
# 640   Free           120291         5924            30  Beginner Level
# 3316   200           114512        22412           304      All Levels
#
#      content_duration   published_timestamp          subject
# ...

# %% [markdown]
# # Q. 6) Which are Least Selling Courses ?

# %%
df.sort_values('num_subscribers').head()
# Out:
#       course_id                                  course_title  is_paid price  \
# 649     1233314                 Building a Balanced Scorecard     True    50
# 3259    1232282     The Cash Flow Statement - An Introduction     True    50
# 3261    1275872               The Complete Adobe Spark Course     True   150
# 910      726314  Create Beautiful Image Maps for Your Website     True    20
# 3328     715476   The Cuckoo Strategy to get European Funding     True   160
#
#       num_subscribers  num_reviews  num_lectures               level  \
# 649                 0            0            11  Intermediate Level
# 3259                0            0            10      Beginner Level
# 3261                0            0            29          All Levels
# 910                 0            0             8  Intermediate Level
# 3328                0            0             6          All Levels
#
#      content_duration   published_timestamp           subject
# ...

# %% [markdown]
# # Q. 7) Show all courses of Graphic Design where the price is below 100 ?

# %%
df['price'] = pd.to_numeric(df['price'], errors='coerce') 

df[(df['subject'] == 'Graphic Design') & (df['price'] < 100)].head()
# Out:
#     course_id                                       course_title  is_paid  \
# 8      206592  :::Beginners Guide To Creating Amazing Images ...     True
# 20    1165268  15  Motion Graphic Elements in After Effect (S...     True
# 35    1164876  3DS MAX - Learn 3Ds MAX tutorial for Beginners...     True
# 39     599652                     48 Logo Designs and Techniques     True
# 52     794036       8 Stunden professionelles Cinema 4D Training     True
#
#     price  num_subscribers  num_reviews  num_lectures               level  \
# 8    25.0               72            5            17      Beginner Level
# 20   30.0                8            0            20  Intermediate Level
# 35   20.0              785            2            29          All Levels
# 39   20.0              113            9            48          All Levels
# 52   50.0               18            1            38          All Levels
#
#    content_duration   published_timestamp         subject
# ...

# %% [markdown]
# # Q. 8) List out all the courses that are related to 'Python'.

# %%
df[df['course_title'].str.contains('Python', case=False)]
# Out:
#       course_id                                       course_title  is_paid  \
# 216      599504  Advanced Scalable Python Web Development Using...     True
# 777       47963  Coding for Entrepreneurs: Learn Python, Django...     True
# 814      631128  Complete Python Web Course: Build 8 Python Web...     True
# 842      186096  Core: A Web App Reference Guide for Django, Py...     True
# 1400     394832  Fun and creative web engineering with Python a...    False
# 1932    1038538            Introduction to QGIS Python Programming     True
# 1969     902888          Investment Portfolio Analysis with Python     True
# 2294     391546        Learn Python and Django: Payment Processing     True
# 2295    1063722            Learn Python Django - A Hands-On Course     True
# 2341     546848  Learn to code in Python and learn Adobe Photos...     True
# 2906     368340    Professional Python Web Development Using Flask     True
# ...

# %% [markdown]
# # Q. 9) What are courses that were published in the year 2015 ?

# %%
df['published_timestamp'] = pd.to_datetime(df['published_timestamp'])
courses_2015 = df[df['published_timestamp'].dt.year == 2015].head()
courses_2015
# Out:
#     course_id                                       course_title  is_paid  \
# 10     591880  1 - Concepts of Statistics For Beginners Step ...     True
# 16     302450        10 Numbers Every Business Owner Should Know     True
# 19     384928  101 Blues riffs - learn how the harmonica supe...     True
# 23     550842  16 Guitar Chords to Jam With - (Beginner - Int...     True
# 26     486240      2 Easy Steps To Investment And Avoiding Traps     True
#
#     price  num_subscribers  num_reviews  num_lectures               level  \
# 10  200.0              273            4            15      Beginner Level
# 16   20.0               13            1             9          All Levels
# 19  200.0             1350           65            55  Intermediate Level
# 23   20.0             1224           19            20      Beginner Level
# 26   20.0              828            1            20          All Levels
#
#    content_duration       published_timestamp              subject
# ...

# %% [markdown]
# # Q. 10) What is the Max. Number of Subscribers for Each Level of courses ?

# %%
df.groupby('level')['num_subscribers'].max()
# Out:
# level
# All Levels            268923
# Beginner Level        161029
# Expert Level            5172
# Intermediate Level     29167
# Name: num_subscribers, dtype: int64

# %% [markdown]
# # UDEMY DATASET Completed
